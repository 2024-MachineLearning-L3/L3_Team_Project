# %% [markdown]
# ## 1. Data Loading

# %%
import pickle

USE_SUBLABEL = False
URL_PER_SITE = 10
TOTAL_URLS   = 950

# Load the pickle file
print("Loading datafile...")
with open("mon_standard.pkl", 'rb') as fi:
    data = pickle.load(fi)

X1 = [] # Array to store instances (timestamps) - 19,000 instances, e.g., [[0.0, 0.5, 3.4, ...], [0.0, 4.5, ...], [0.0, 1.5, ...], ... [... ,45.8]]
X2 = [] # Array to store instances (direction*size) - size information
y = [] # Array to store the site of each instance - 19,000 instances, e.g., [0, 0, 0, 0, 0, 0, ..., 94, 94, 94, 94, 94]

# Differentiate instances and sites, and store them in the respective x and y arrays
# x array (direction*timestamp), y array (site label)
for i in range(TOTAL_URLS):
    if USE_SUBLABEL:
        label = i
    else:
        label = i // URL_PER_SITE # Calculate which site's URL the current URL being processed belongs to and set that value as the label. Thus, URLs fetched from the same site are labeled identically.
    for sample in data[i]:
        size_seq = []
        time_seq = []
        for c in sample:
            dr = 1 if c > 0 else -1
            time_seq.append(abs(c))
            size_seq.append(dr * 512)
        X1.append(time_seq)
        X2.append(size_seq)
        y.append(label)
size = len(y)

print(f'Total samples: {size}') # Output: 19000
# Out:
# Loading datafile...
# Total samples: 19000

# %% [markdown]
# ## 2. Feature Engineering

# %%
import numpy as np
from itertools import groupby

# Initialize a list to store all features
features = []

# Feature extraction
for i in range(len(X2)):
    size_seq = X2[i]
    time_seq = X1[i]
    
    # 1. Number of incoming packets
    num_incoming_packets = sum(1 for size in size_seq if size < 0)
    
    # 2. Total number of packets
    num_total_packets = len(size_seq)
    
    # 3. Number of outgoing packets
    num_outgoing_packets = sum(1 for size in size_seq if size > 0)
    
    # 4. Proportion of outgoing packets
    ratio_outgoing = num_outgoing_packets / num_total_packets if num_total_packets > 0 else 0
    
    # 5. Proportion of incoming packets
    ratio_incoming = num_incoming_packets / num_total_packets if num_total_packets > 0 else 0
    
    # 6. Proportion of incoming packets in the first 30 packets
    incoming_first_30 = sum(1 for size in size_seq[:30] if size < 0) / 30 if num_total_packets >= 30 else 0
    
    # 7. Proportion of outgoing packets in the first 30 packets
    outgoing_first_30 = sum(1 for size in size_seq[:30] if size > 0) / 30 if num_total_packets >= 30 else 0
    
    # 8. Maximum number of packets in outgoing bursts
    burst_outgoing_max = max(len(list(g)) for k, g in groupby(size_seq) if k > 0) if num_outgoing_packets > 0 else 0
    
    # 9. Standard deviation of outgoing burst sizes
    outgoing_burst_std = np.std([len(list(g)) for k, g in groupby(size_seq) if k > 0])
    
    # 10. Average size of outgoing bursts
    outgoing_burst_avg = np.mean([len(list(g)) for k, g in groupby(size_seq) if k > 0])
    
    # 11. Number of outgoing bursts
    num_outgoing_bursts = len([1 for k, g in groupby(size_seq) if k > 0])
    
    # 12. Number of incoming bursts
    num_incoming_bursts = len([1 for k, g in groupby(size_seq) if k < 0])
    
    # 13. Average number of incoming packets per second
    incoming_per_second_avg = num_incoming_packets / (len(time_seq) / 60) if len(time_seq) > 0 else 0

    # 14. Total transmission time
    total_time = sum(time_seq)

    # 15. Average time interval in the last 5 seconds
    last_5_seconds_time_intervals = np.mean([time_seq[i+1] - time_seq[i] for i in range(len(time_seq)-1) if time_seq[i] > 0]) if len(time_seq) > 1 else 0
    
    # 16. Sum of packet sizes
    sum_packets = sum(size_seq)
    
    # 17. Packets per second
    packets_per_second = len(size_seq) / sum(time_seq) if sum(time_seq) > 0 else 0
    
    # 18. Mean packets per second
    packets_per_second_values = [1 / t for t in time_seq if t > 0]
    
    # 19. mean of the packets per second values
    mean_packets_per_second = np.mean(packets_per_second_values) if packets_per_second_values else 0
    
    # 20. Standard deviation of packets per second
    std_packets_per_second = np.std(packets_per_second_values) if packets_per_second_values else 0
    
    # 21. Transmission time Q1 (25th percentile)
    transmission_time_Q1 = np.percentile(time_seq, 25) if len(time_seq) > 0 else 0
    
    # 22. Transmission time Q2 (median)
    transmission_time_Q2 = np.percentile(time_seq, 50) if len(time_seq) > 0 else 0
    
    # 23. Transmission time Q3 (75th percentile)
    transmission_time_Q3 = np.percentile(time_seq, 75) if len(time_seq) > 0 else 0
    
    # 24. Transmission time Q4 (maximum)
    transmission_time_Q4 = np.percentile(time_seq, 100) if len(time_seq) > 0 else 0
    
    # 25. Average ordering of outgoing packets
    outgoing_order = [i for i, size in enumerate(size_seq) if size > 0]
    average_outgoing_ordering = np.mean(outgoing_order) if outgoing_order else 0
    
    # 26. Standard deviation of outgoing packet ordering
    std_dev_outgoing_ordering = np.std(outgoing_order) if outgoing_order else 0
    
    # Add all features to the list
    features.append([
        num_incoming_packets, num_total_packets, num_outgoing_packets, ratio_outgoing,
        ratio_incoming, incoming_first_30, outgoing_first_30, burst_outgoing_max,
        outgoing_burst_std, outgoing_burst_avg, num_outgoing_bursts,
        num_incoming_bursts, incoming_per_second_avg,  total_time,
        last_5_seconds_time_intervals, 
        sum_packets, packets_per_second, mean_packets_per_second, std_packets_per_second,
        transmission_time_Q1, transmission_time_Q2, transmission_time_Q3, transmission_time_Q4,
        average_outgoing_ordering, std_dev_outgoing_ordering
    ])

# Convert the feature list to a numpy array
features = np.array(features)

# Labels for each sample
y = np.array(y)

# %% [markdown]
# ## 3. Data Splitting and Scaling

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# data split
X_train, X_test, y_train, y_test = train_test_split(features, y, test_size=0.2, random_state=42, stratify=y)

# scale
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## 4. Training the Random Forest model

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(
    n_estimators=110,
    max_depth=35,
    max_features=0.5,
    random_state=42
)

rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=35, max_features=0.5, n_estimators=110,
#                        random_state=42)

# %% [markdown]
# ## 5. Hyperparameter Tuning

# %%
import time
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, uniform

param_dist = {
    'n_estimators': [110, 300, 1000, 2000],
    'max_depth': [25, 35, 50],
    'max_features': ['sqrt', 'log2', 0.5],
    'min_samples_leaf': [2, 5]
}

# RandomizedSearchCV randomly samples from the hyperparameter grid
random_search = RandomizedSearchCV(rf_model, param_distributions=param_dist, n_iter=50, cv=3, verbose=2, random_state=42)

random_search.fit(X_train, y_train)

print("Best Parameters:", random_search.best_params_)
best_model = random_search.best_estimator_
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, n_estimators=110; total time=   7.4s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, n_estimators=110; total time=   7.3s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, n_estimators=110; total time=   8.4s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=5, n_estimators=1000; total time=  52.3s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=5, n_estimators=1000; total time=  52.7s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=5, n_estimators=1000; total time=  51.8s
# [CV] END max_depth=25, max_features=0.5, min_samples_leaf=2, n_estimators=1000; total time= 2.8min
# [CV] END max_depth=25, max_features=0.5, min_samples_leaf=2, n_estimators=1000; total time= 2.9min
# [CV] END max_depth=25, max_features=0.5, min_samples_leaf=2, n_estimators=1000; total time= 2.8min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, n_estimators=110; total time=   8.0s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, n_estimators=110; total time=   8.0s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, n_estimators=110; total time=   7.9s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=5, n_estimators=110; total time=   6.9s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=5, n_estimators=110; total time=   7.1s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=5, n_estimators=110; total time=   6.9s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=2, n_estimators=1000; total time= 1.2min
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=2, n_estimators=1000; total time= 1.2min
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=2, n_estimators=1000; total time= 1.2min
# [CV] END max_depth=25, max_features=log2, min_samples_leaf=2, n_estimators=1000; total time= 1.0min
# [CV] END max_depth=25, max_features=log2, min_samples_leaf=2, n_estimators=1000; total time=  59.6s
# [CV] END max_depth=25, max_features=log2, min_samples_leaf=2, n_estimators=1000; total time=  59.3s
# [CV] END max_depth=35, max_features=log2, min_samples_leaf=2, n_estimators=1000; total time=  59.0s
# [CV] END max_depth=35, max_features=log2, min_samples_leaf=2, n_estimators=1000; total time= 1.1min
# [CV] END max_depth=35, max_features=log2, min_samples_leaf=2, n_estimators=1000; total time=  59.7s
# [CV] END max_depth=25, max_features=log2, min_samples_leaf=5, n_estimators=110; total time=   5.7s
# [CV] END max_depth=25, max_features=log2, min_samples_leaf=5, n_estimators=110; total time=   5.9s
# [CV] END max_depth=25, max_features=log2, min_samples_leaf=5, n_estimators=110; total time=   5.6s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, n_estimators=1000; total time= 1.1min
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, n_estimators=1000; total time= 1.1min
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, n_estimators=1000; total time= 1.1min
# [CV] END max_depth=35, max_features=0.5, min_samples_leaf=5, n_estimators=2000; total time= 5.0min
# [CV] END max_depth=35, max_features=0.5, min_samples_leaf=5, n_estimators=2000; total time= 5.1min
# [CV] END max_depth=35, max_features=0.5, min_samples_leaf=5, n_estimators=2000; total time= 5.1min
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=5, n_estimators=2000; total time= 2.1min
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=5, n_estimators=2000; total time= 2.2min
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=5, n_estimators=2000; total time= 2.1min
# [CV] END max_depth=25, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=  18.0s
# [CV] END max_depth=25, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=  18.2s
# [CV] END max_depth=25, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=  17.8s
# [CV] END max_depth=35, max_features=0.5, min_samples_leaf=5, n_estimators=300; total time=  45.1s
# [CV] END max_depth=35, max_features=0.5, min_samples_leaf=5, n_estimators=300; total time=  46.4s
# [CV] END max_depth=35, max_features=0.5, min_samples_leaf=5, n_estimators=300; total time=  45.9s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, n_estimators=300; total time=  19.2s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, n_estimators=300; total time=  19.3s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, n_estimators=300; total time=  19.1s
# [CV] END max_depth=25, max_features=0.5, min_samples_leaf=5, n_estimators=1000; total time= 2.5min
# [CV] END max_depth=25, max_features=0.5, min_samples_leaf=5, n_estimators=1000; total time= 2.6min
# [CV] END max_depth=25, max_features=0.5, min_samples_leaf=5, n_estimators=1000; total time= 2.5min
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=2, n_estimators=110; total time=   6.5s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=2, n_estimators=110; total time=   6.5s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=2, n_estimators=110; total time=   6.4s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=  21.9s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=  21.9s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=  22.1s
# [CV] END max_depth=35, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=  17.6s
# [CV] END max_depth=35, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=  17.8s
# [CV] END max_depth=35, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=  17.8s
# [CV] END max_depth=35, max_features=log2, min_samples_leaf=5, n_estimators=2000; total time= 1.7min
# [CV] END max_depth=35, max_features=log2, min_samples_leaf=5, n_estimators=2000; total time= 1.8min
# [CV] END max_depth=35, max_features=log2, min_samples_leaf=5, n_estimators=2000; total time= 1.7min
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=2, n_estimators=2000; total time= 2.1min
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=2, n_estimators=2000; total time= 2.0min
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=2, n_estimators=2000; total time= 2.0min
# [CV] END max_depth=25, max_features=0.5, min_samples_leaf=2, n_estimators=110; total time=  18.9s
# [CV] END max_depth=25, max_features=0.5, min_samples_leaf=2, n_estimators=110; total time=  19.0s
# [CV] END max_depth=25, max_features=0.5, min_samples_leaf=2, n_estimators=110; total time=  19.1s
# [CV] END max_depth=35, max_features=log2, min_samples_leaf=2, n_estimators=2000; total time= 2.0min
# [CV] END max_depth=35, max_features=log2, min_samples_leaf=2, n_estimators=2000; total time= 2.0min
# [CV] END max_depth=35, max_features=log2, min_samples_leaf=2, n_estimators=2000; total time= 2.0min
# [CV] END max_depth=35, max_features=0.5, min_samples_leaf=5, n_estimators=110; total time=  16.9s
# [CV] END max_depth=35, max_features=0.5, min_samples_leaf=5, n_estimators=110; total time=  16.7s
# [CV] END max_depth=35, max_features=0.5, min_samples_leaf=5, n_estimators=110; total time=  16.5s
# [CV] END max_depth=50, max_features=0.5, min_samples_leaf=5, n_estimators=300; total time=  45.6s
# [CV] END max_depth=50, max_features=0.5, min_samples_leaf=5, n_estimators=300; total time=  46.4s
# [CV] END max_depth=50, max_features=0.5, min_samples_leaf=5, n_estimators=300; total time=  46.4s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, n_estimators=2000; total time= 2.1min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, n_estimators=2000; total time= 2.1min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, n_estimators=2000; total time= 2.1min
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, n_estimators=2000; total time= 2.1min
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, n_estimators=2000; total time= 2.2min
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, n_estimators=2000; total time= 2.2min
# [CV] END max_depth=35, max_features=0.5, min_samples_leaf=2, n_estimators=1000; total time= 2.9min
# [CV] END max_depth=35, max_features=0.5, min_samples_leaf=2, n_estimators=1000; total time= 2.9min
# [CV] END max_depth=35, max_features=0.5, min_samples_leaf=2, n_estimators=1000; total time= 2.9min
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=5, n_estimators=1000; total time= 1.1min
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=5, n_estimators=1000; total time= 1.1min
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=5, n_estimators=1000; total time= 1.1min
# [CV] END max_depth=35, max_features=0.5, min_samples_leaf=5, n_estimators=1000; total time= 2.7min
# [CV] END max_depth=35, max_features=0.5, min_samples_leaf=5, n_estimators=1000; total time= 2.6min
# [CV] END max_depth=35, max_features=0.5, min_samples_leaf=5, n_estimators=1000; total time= 2.5min
# [CV] END max_depth=50, max_features=0.5, min_samples_leaf=5, n_estimators=2000; total time= 5.1min
# [CV] END max_depth=50, max_features=0.5, min_samples_leaf=5, n_estimators=2000; total time= 5.3min
# [CV] END max_depth=50, max_features=0.5, min_samples_leaf=5, n_estimators=2000; total time= 5.3min
# [CV] END max_depth=25, max_features=0.5, min_samples_leaf=2, n_estimators=2000; total time= 6.0min
# [CV] END max_depth=25, max_features=0.5, min_samples_leaf=2, n_estimators=2000; total time= 5.8min
# [CV] END max_depth=25, max_features=0.5, min_samples_leaf=2, n_estimators=2000; total time= 5.7min
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=2, n_estimators=1000; total time= 1.0min
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=2, n_estimators=1000; total time= 1.1min
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=2, n_estimators=1000; total time= 1.0min
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=  21.7s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=  22.4s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=  22.5s
# [CV] END max_depth=35, max_features=0.5, min_samples_leaf=2, n_estimators=110; total time=  18.7s
# [CV] END max_depth=35, max_features=0.5, min_samples_leaf=2, n_estimators=110; total time=  19.2s
# [CV] END max_depth=35, max_features=0.5, min_samples_leaf=2, n_estimators=110; total time=  19.0s
# [CV] END max_depth=25, max_features=log2, min_samples_leaf=5, n_estimators=300; total time=  15.4s
# [CV] END max_depth=25, max_features=log2, min_samples_leaf=5, n_estimators=300; total time=  15.6s
# [CV] END max_depth=25, max_features=log2, min_samples_leaf=5, n_estimators=300; total time=  15.6s
# [CV] END max_depth=50, max_features=0.5, min_samples_leaf=2, n_estimators=110; total time=  18.9s
# [CV] END max_depth=50, max_features=0.5, min_samples_leaf=2, n_estimators=110; total time=  19.1s
# [CV] END max_depth=50, max_features=0.5, min_samples_leaf=2, n_estimators=110; total time=  18.6s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, n_estimators=2000; total time= 2.4min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, n_estimators=2000; total time= 2.5min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, n_estimators=2000; total time= 2.4min
# [CV] END max_depth=25, max_features=0.5, min_samples_leaf=2, n_estimators=300; total time=  50.4s
# [CV] END max_depth=25, max_features=0.5, min_samples_leaf=2, n_estimators=300; total time=  52.2s
# [CV] END max_depth=25, max_features=0.5, min_samples_leaf=2, n_estimators=300; total time=  51.3s
# [CV] END max_depth=35, max_features=log2, min_samples_leaf=5, n_estimators=1000; total time=  51.7s
# [CV] END max_depth=35, max_features=log2, min_samples_leaf=5, n_estimators=1000; total time=  52.0s
# [CV] END max_depth=35, max_features=log2, min_samples_leaf=5, n_estimators=1000; total time=  51.5s
# [CV] END max_depth=25, max_features=log2, min_samples_leaf=2, n_estimators=110; total time=   6.5s
# [CV] END max_depth=25, max_features=log2, min_samples_leaf=2, n_estimators=110; total time=   6.5s
# [CV] END max_depth=25, max_features=log2, min_samples_leaf=2, n_estimators=110; total time=   6.5s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=  17.6s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=  17.7s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=  17.9s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, n_estimators=1000; total time= 1.1min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, n_estimators=1000; total time= 1.1min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, n_estimators=1000; total time= 1.1min
# [CV] END max_depth=35, max_features=log2, min_samples_leaf=5, n_estimators=110; total time=   5.7s
# [CV] END max_depth=35, max_features=log2, min_samples_leaf=5, n_estimators=110; total time=   5.8s
# [CV] END max_depth=35, max_features=log2, min_samples_leaf=5, n_estimators=110; total time=   5.7s
# [CV] END max_depth=50, max_features=0.5, min_samples_leaf=2, n_estimators=1000; total time= 3.1min
# [CV] END max_depth=50, max_features=0.5, min_samples_leaf=2, n_estimators=1000; total time= 2.9min
# [CV] END max_depth=50, max_features=0.5, min_samples_leaf=2, n_estimators=1000; total time= 2.9min
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, n_estimators=300; total time=  19.6s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, n_estimators=300; total time=  19.8s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, n_estimators=300; total time=  19.4s
# [CV] END max_depth=50, max_features=0.5, min_samples_leaf=5, n_estimators=1000; total time= 2.5min
# [CV] END max_depth=50, max_features=0.5, min_samples_leaf=5, n_estimators=1000; total time= 2.6min
# [CV] END max_depth=50, max_features=0.5, min_samples_leaf=5, n_estimators=1000; total time= 2.5min
# [CV] END max_depth=25, max_features=log2, min_samples_leaf=5, n_estimators=2000; total time= 1.7min
# [CV] END max_depth=25, max_features=log2, min_samples_leaf=5, n_estimators=2000; total time= 1.8min
# [CV] END max_depth=25, max_features=log2, min_samples_leaf=5, n_estimators=2000; total time= 1.7min
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=2, n_estimators=2000; total time= 2.4min
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=2, n_estimators=2000; total time= 2.4min
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=2, n_estimators=2000; total time= 2.4min
# [CV] END max_depth=35, max_features=0.5, min_samples_leaf=2, n_estimators=300; total time=  53.6s
# [CV] END max_depth=35, max_features=0.5, min_samples_leaf=2, n_estimators=300; total time=  52.4s
# [CV] END max_depth=35, max_features=0.5, min_samples_leaf=2, n_estimators=300; total time=  51.2s
# Best Parameters: {'n_estimators': 2000, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 35}

# %% [markdown]
# ## 6. Model Evaluation

# %%
from sklearn.metrics import accuracy_score, auc, confusion_matrix, precision_score, precision_recall_curve, roc_curve, recall_score, f1_score, classification_report

y_pred = best_model.predict(X_test)

# Calculate Accuracy, Precison, Recall, F1 Score 
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average = 'weighted')
recall = recall_score(y_test, y_pred, average = 'weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

# Calculate Confusion Matrix, ROC AUC, PR AUC
conf_matrix = confusion_matrix(y_test, y_pred)

# Classification Report
class_report = classification_report(y_test, y_pred, target_names=[f'Class {i}' for i in range(95)])

# Results
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision (Weighted): {precision:.4f}")
print(f"Recall (Weighted): {recall:.4f}")
print(f"F1 Score (Weighted): {f1:.4f}")

print(f"\nConfusion Matrix\n{conf_matrix}")
print("\nClassification Report:\n", class_report)
# Out:
# Accuracy: 0.7937
# Precision (Weighted): 0.7966
# Recall (Weighted): 0.7937
# F1 Score (Weighted): 0.7913
#
# Confusion Matrix
# [[23  0  0 ...  0  0  0]
#  [ 0 32  0 ...  0  0  0]
#  [ 0  0 36 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 25  0  3]
#  [ 0  0  0 ...  0 39  0]
#  [ 0  0  0 ...  0  0 29]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      Class 0       0.79      0.57      0.67        40
#      Class 1       0.89      0.80      0.84        40
#      Class 2       0.90      0.90      0.90        40
#      Class 3       0.88      0.88      0.88        40
#      Class 4       0.74      0.85      0.79        40
#      Class 5       0.85      0.85      0.85        40
#      Class 6       0.69      0.88      0.77        40
#      Class 7       0.83      1.00      0.91        40
#      Class 8       0.88      0.88      0.88        40
#      Class 9       0.76      0.78      0.77        40
#     Class 10       0.97      0.80      0.88        40
#     Class 11       0.81      0.72      0.76        40
#     Class 12       0.88      0.93      0.90        40
#     Class 13       0.67      0.40      0.50        40
#     Class 14       0.74      0.70      0.72        40
#     Class 15       0.75      0.82      0.79        40
#     Class 16       0.77      0.60      0.68        40
#     Class 17       0.72      0.78      0.75        40
#     Class 18       0.85      0.88      0.86        40
#     Class 19       0.83      0.88      0.85        40
#     Class 20       0.89      0.97      0.93        40
#     Class 21       0.79      0.78      0.78        40
#     Class 22       0.71      0.72      0.72        40
#     Class 23       0.83      0.85      0.84        40
#     Class 24       0.45      0.42      0.44        40
#     Class 25       0.91      0.72      0.81        40
#     Class 26       0.78      1.00      0.88        40
#     Class 27       0.81      0.75      0.78        40
#     Class 28       0.88      0.90      0.89        40
#     Class 29       0.70      0.80      0.74        40
#     Class 30       0.76      0.85      0.80        40
#     Class 31       0.90      0.95      0.93        40
#     Class 32       0.64      0.57      0.61        40
#     Class 33       0.80      0.70      0.75        40
#     Class 34       0.76      0.62      0.68        40
#     Class 35       0.79      0.78      0.78        40
#     Class 36       0.81      0.88      0.84        40
#     Class 37       0.83      0.62      0.71        40
#     Class 38       0.62      0.78      0.69        40
#     Class 39       0.74      0.80      0.77        40
#     Class 40       0.76      0.85      0.80        40
#     Class 41       0.77      0.93      0.84        40
#     Class 42       0.74      0.72      0.73        40
#     Class 43       0.89      0.85      0.87        40
#     Class 44       0.86      0.93      0.89        40
#     Class 45       0.72      0.65      0.68        40
#     Class 46       0.89      0.80      0.84        40
#     Class 47       0.69      0.72      0.71        40
#     Class 48       1.00      0.88      0.93        40
#     Class 49       0.86      0.93      0.89        40
#     Class 50       0.74      0.70      0.72        40
#     Class 51       0.71      0.68      0.69        40
#     Class 52       0.81      0.88      0.84        40
#     Class 53       0.74      0.78      0.76        40
#     Class 54       0.95      0.88      0.91        40
#     Class 55       0.72      0.65      0.68        40
#     Class 56       0.88      0.90      0.89        40
#     Class 57       0.84      0.80      0.82        40
#     Class 58       0.81      0.97      0.89        40
#     Class 59       0.97      0.80      0.88        40
#     Class 60       0.87      0.85      0.86        40
#     Class 61       0.76      0.72      0.74        40
#     Class 62       0.64      0.75      0.69        40
#     Class 63       0.76      0.65      0.70        40
#     Class 64       0.76      0.78      0.77        40
#     Class 65       0.85      0.70      0.77        40
#     Class 66       0.76      0.88      0.81        40
#     Class 67       0.89      0.85      0.87        40
#     Class 68       0.79      0.78      0.78        40
#     Class 69       0.76      0.80      0.78        40
#     Class 70       0.91      0.97      0.94        40
#     Class 71       0.82      0.70      0.76        40
#     Class 72       0.94      0.78      0.85        40
#     Class 73       0.83      0.95      0.88        40
#     Class 74       0.58      0.82      0.68        40
#     Class 75       0.93      0.97      0.95        40
#     Class 76       0.90      0.90      0.90        40
#     Class 77       0.61      0.47      0.54        40
#     Class 78       0.79      0.68      0.73        40
#     Class 79       0.70      0.80      0.74        40
#     Class 80       0.84      0.90      0.87        40
#     Class 81       0.79      0.82      0.80        40
#     Class 82       0.87      0.65      0.74        40
#     Class 83       0.75      0.90      0.82        40
#     Class 84       0.74      0.65      0.69        40
#     Class 85       0.90      0.88      0.89        40
#     Class 86       0.83      1.00      0.91        40
#     Class 87       0.79      0.85      0.82        40
#     Class 88       0.75      0.75      0.75        40
#     Class 89       0.64      0.53      0.58        40
#     Class 90       0.89      0.80      0.84        40
#     Class 91       0.84      0.93      0.88        40
#     Class 92       0.81      0.62      0.70        40
#     Class 93       0.85      0.97      0.91        40
#     Class 94       0.59      0.72      0.65        40
#
#     accuracy                           0.79      3800
#    macro avg       0.80      0.79      0.79      3800
# weighted avg       0.80      0.79      0.79      3800
